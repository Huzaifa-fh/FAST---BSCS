# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Metrics
accuracy = 0.9725301204819277
precision = 0.9606003752345216
recall = 0.9855630413859481
f1_score = 0.9729216152019003
roc_auc_score = 0.9725112504227037
confusion_matrix = np.array([[994, 42], [15, 1024]])

# Creating a figure for subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Confusion Matrix
sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap='Blues', ax=axs[0, 0])
axs[0, 0].set_title("Confusion Matrix")
axs[0, 0].set_xlabel("Predicted label")
axs[0, 0].set_ylabel("True label")

# Bar plot for other metrics
metrics = {"Accuracy": accuracy, "Precision": precision, "Recall": recall, "F1 Score": f1_score, "ROC AUC Score": roc_auc_score}
axs[0, 1].bar(metrics.keys(), metrics.values(), color=['blue', 'green', 'red', 'purple', 'orange'])
axs[0, 1].set_ylim(0.95, 1.0)
axs[0, 1].set_title("Performance Metrics")
axs[0, 1].set_ylabel("Score")

# Hide unused subplots
axs[1, 0].axis('off')
axs[1, 1].axis('off')

# Add overall title
fig.suptitle("Random Forest Model Metrics")

# Adjust layout and save the figure without white spaces
plt.tight_layout()
plt.savefig('./', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Metrics for Logistic Regression
accuracy_lr = 0.9686746987951808
precision_lr = 0.9484346224677717
recall_lr = 0.9913378248315688
f1_score_lr = 0.9694117647058824
roc_auc_score_lr = 0.9686418853887575
confusion_matrix_lr = np.array([[980, 56], [9, 1030]])

# Creating a figure for subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Confusion Matrix
sns.heatmap(confusion_matrix_lr, annot=True, fmt="d", cmap='Blues', ax=axs[0, 0])
axs[0, 0].set_title("Confusion Matrix")
axs[0, 0].set_xlabel("Predicted label")
axs[0, 0].set_ylabel("True label")

# Bar plot for other metrics
metrics_lr = {"Accuracy": accuracy_lr, "Precision": precision_lr, "Recall": recall_lr, "F1 Score": f1_score_lr, "ROC AUC Score": roc_auc_score_lr}
axs[0, 1].bar(metrics_lr.keys(), metrics_lr.values(), color=['blue', 'green', 'red', 'purple', 'orange'])
axs[0, 1].set_ylim(0.94, 1.0)
axs[0, 1].set_title("Performance Metrics")
axs[0, 1].set_ylabel("Score")

# Hide unused subplots
axs[1, 0].axis('off')
axs[1, 1].axis('off')

# Add overall title
fig.suptitle("Logistic Regression Metrics")

# Adjust layout and save the figure without white spaces
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Metrics for Support Vector Classifier (SVC)
accuracy_svc = 0.9426506024096386
precision_svc = 0.9356060606060606
recall_svc = 0.9509143407122232
f1_score_svc = 0.943198090692124
roc_auc_score_svc = 0.9426386375375789
confusion_matrix_svc = np.array([[968, 68], [51, 988]])

# Creating a figure for subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Confusion Matrix
sns.heatmap(confusion_matrix_svc, annot=True, fmt="d", cmap='Blues', ax=axs[0, 0])
axs[0, 0].set_title("Confusion Matrix")
axs[0, 0].set_xlabel("Predicted label")
axs[0, 0].set_ylabel("True label")

# Bar plot for other metrics
metrics_svc = {"Accuracy": accuracy_svc, "Precision": precision_svc, "Recall": recall_svc, "F1 Score": f1_score_svc, "ROC AUC Score": roc_auc_score_svc}
axs[0, 1].bar(metrics_svc.keys(), metrics_svc.values(), color=['blue', 'green', 'red', 'purple', 'orange'])
axs[0, 1].set_ylim(0.92, 1.0)
axs[0, 1].set_title("Performance Metrics")
axs[0, 1].set_ylabel("Score")

# Hide unused subplots
axs[1, 0].axis('off')
axs[1, 1].axis('off')

# Add overall title
fig.suptitle("Support Vector Classifier Metrics")

# Adjust layout and save the figure without white spaces
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Metrics for Tuned Random Forest
accuracy_tuned_rf = 0.9898795180722891
precision_tuned_rf = 0.9856870229007634
recall_tuned_rf = 0.9942252165543792
f1_score_tuned_rf = 0.9899377096310494
roc_auc_score_tuned_rf = 0.9898732260378074
confusion_matrix_tuned_rf = np.array([[1021, 15], [6, 1033]])

# Creating a figure for subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Confusion Matrix
sns.heatmap(confusion_matrix_tuned_rf, annot=True, fmt="d", cmap='Blues', ax=axs[0, 0])
axs[0, 0].set_title("Confusion Matrix")
axs[0, 0].set_xlabel("Predicted label")
axs[0, 0].set_ylabel("True label")

# Bar plot for other metrics
metrics_tuned_rf = {"Accuracy": accuracy_tuned_rf, "Precision": precision_tuned_rf, "Recall": recall_tuned_rf, "F1 Score": f1_score_tuned_rf, "ROC AUC Score": roc_auc_score_tuned_rf}
axs[0, 1].bar(metrics_tuned_rf.keys(), metrics_tuned_rf.values(), color=['blue', 'green', 'red', 'purple', 'orange'])
axs[0, 1].set_ylim(0.98, 1.0)
axs[0, 1].set_title("Performance Metrics")
axs[0, 1].set_ylabel("Score")

# Hide unused subplots
axs[1, 0].axis('off')
axs[1, 1].axis('off')

# Add overall title
fig.suptitle("Tuned Random Forest Metrics")

# Adjust layout and save the figure without white spaces
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Metrics for Tuned Logistic Regression
accuracy_tuned_lr = 0.9783132530120482
precision_tuned_lr = 0.9636194029850746
recall_tuned_lr = 0.9942252165543792
f1_score_tuned_lr = 0.9786830885836096
roc_auc_score_tuned_lr = 0.9782902144547958
confusion_matrix_tuned_lr = np.array([[997, 39], [6, 1033]])

# Creating a figure for subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Confusion Matrix
sns.heatmap(confusion_matrix_tuned_lr, annot=True, fmt="d", cmap='Blues', ax=axs[0, 0])
axs[0, 0].set_title("Confusion Matrix")
axs[0, 0].set_xlabel("Predicted label")
axs[0, 0].set_ylabel("True label")

# Bar plot for other metrics
metrics_tuned_lr = {"Accuracy": accuracy_tuned_lr, "Precision": precision_tuned_lr, "Recall": recall_tuned_lr, "F1 Score": f1_score_tuned_lr, "ROC AUC Score": roc_auc_score_tuned_lr}
axs[0, 1].bar(metrics_tuned_lr.keys(), metrics_tuned_lr.values(), color=['blue', 'green', 'red', 'purple', 'orange'])
axs[0, 1].set_ylim(0.96, 1.0)
axs[0, 1].set_title("Performance Metrics")
axs[0, 1].set_ylabel("Score")

# Hide unused subplots
axs[1, 0].axis('off')
axs[1, 1].axis('off')

# Add overall title
fig.suptitle("Tuned Logistic Regression Metrics")

# Adjust layout and save the figure without white spaces
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Metrics for Tuned Support Vector Classifier (SVC)
accuracy_tuned_svc = 0.9773493975903614
precision_tuned_svc = 0.9618249534450651
recall_tuned_svc = 0.9942252165543792
f1_score_tuned_svc = 0.9777567439659252
roc_auc_score_tuned_svc = 0.9773249634895449
confusion_matrix_tuned_svc = np.array([[995, 41], [6, 1033]])

# Creating a figure for subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Confusion Matrix
sns.heatmap(confusion_matrix_tuned_svc, annot=True, fmt="d", cmap='Blues', ax=axs[0, 0])
axs[0, 0].set_title("Confusion Matrix")
axs[0, 0].set_xlabel("Predicted label")
axs[0, 0].set_ylabel("True label")

# Bar plot for other metrics
metrics_tuned_svc = {"Accuracy": accuracy_tuned_svc, "Precision": precision_tuned_svc, "Recall": recall_tuned_svc, "F1 Score": f1_score_tuned_svc, "ROC AUC Score": roc_auc_score_tuned_svc}
axs[0, 1].bar(metrics_tuned_svc.keys(), metrics_tuned_svc.values(), color=['blue', 'green', 'red', 'purple', 'orange'])
axs[0, 1].set_ylim(0.96, 1.0)
axs[0, 1].set_title("Performance Metrics")
axs[0, 1].set_ylabel("Score")

# Hide unused subplots
axs[1, 0].axis('off')
axs[1, 1].axis('off')

# Add overall title
fig.suptitle("Tuned Support Vector Classifier Metrics")

# Adjust layout and save the figure without white spaces
plt.tight_layout()
plt.show()
